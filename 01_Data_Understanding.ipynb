# %%
import pandas as pd

cpi = pd.read_csv("../data/historicalcpi.csv")
ppi = pd.read_csv("../data/historicalppi.csv")
forecast = pd.read_csv("../data/CPIForecast.csv")

print("CPI Shape:", cpi.shape)
print("PPI Shape:", ppi.shape)
print("Forecast Shape:", forecast.shape)
# Out:
# CPI Shape: (1144, 3)
# PPI Shape: (832, 3)
# Forecast Shape: (242, 8)

# %%
print("CPI Columns")
print(cpi.columns.tolist())

print("\nPPI Columns")
print(ppi.columns.tolist())

print("\nForecast Columns")
print(forecast.columns.tolist())
# Out:
# CPI Columns
# ['Consumer Price Index item', 'Year', 'Percent change']
#
# PPI Columns
# ['Producer Price Index item', 'Year', 'Percent change']
#
# Forecast Columns
# ['Top-level', 'Aggregate', 'Mid-level', 'Low-level', 'Disaggregate', 'Attribute', 'Unit', 'Value']

# %%
cpi.head(10)
# Out:
#   Consumer Price Index item  Year  Percent change
# 0                  All food  1974            14.3
# 1                  All food  1975             8.5
# 2                  All food  1976             3.0
# 3                  All food  1977             6.3
# 4                  All food  1978             9.9
# 5                  All food  1979            11.0
# 6                  All food  1980             8.6
# 7                  All food  1981             7.8
# 8                  All food  1982             4.1
# 9                  All food  1983             2.1

# %%
ppi.head(10)
# Out:
#                Producer Price Index item  Year  Percent change
# 0  Unprocessed foodstuffs and feedstuffs  1974             5.2
# 1  Unprocessed foodstuffs and feedstuffs  1975             1.3
# 2  Unprocessed foodstuffs and feedstuffs  1976            -0.8
# 3  Unprocessed foodstuffs and feedstuffs  1977             0.9
# 4  Unprocessed foodstuffs and feedstuffs  1978            12.6
# 5  Unprocessed foodstuffs and feedstuffs  1979            14.5
# 6  Unprocessed foodstuffs and feedstuffs  1980             4.6
# 7  Unprocessed foodstuffs and feedstuffs  1981            -0.7
# 8  Unprocessed foodstuffs and feedstuffs  1982            -3.8
# 9  Unprocessed foodstuffs and feedstuffs  1983             1.8

# %%
forecast.head(10)
# Out:
#   Top-level Aggregate Mid-level Low-level Disaggregate  \
# 0  All food       NaN       NaN       NaN          NaN
# 1  All food       NaN       NaN       NaN          NaN
# 2  All food       NaN       NaN       NaN          NaN
# 3  All food       NaN       NaN       NaN          NaN
# 4  All food       NaN       NaN       NaN          NaN
# 5  All food       NaN       NaN       NaN          NaN
# 6  All food       NaN       NaN       NaN          NaN
# 7  All food       NaN       NaN       NaN          NaN
# 8  All food       NaN       NaN       NaN          NaN
# 9  All food       NaN       NaN       NaN          NaN
#
#                                  Attribute            Unit  Value
# 0                      Relative importance         Percent  100.0
# 1  Month-to-month March 2026 to April 2026  Percent change    0.5
# 2  Year-over-year April 2025 to April 2026  Percent change    3.2
# 3      Year-to-date avg. 2026 to avg. 2025  Percent change    2.0
# ...

# %%
cpi["Consumer Price Index item"].unique()[:20]
# Out:
# array(['All food', 'Food away from home', 'Food at home',
#        'Meats, poultry, and fish', 'Meats', 'Beef and veal', 'Pork',
#        'Other meats', 'Poultry', 'Fish and seafood', 'Eggs',
#        'Dairy products', 'Fats and oils', 'Fruits and vegetables',
#        'Fresh fruits and vegetables', 'Fresh fruits', 'Fresh vegetables',
#        'Processed fruits and vegetables', 'Sugar and sweets',
#        'Cereals and bakery products'], dtype=object)

# %%
ppi["Producer Price Index item"].unique()[:20]
# Out:
# array(['Unprocessed foodstuffs and feedstuffs',
#        'Processed foods and feeds', 'Finished consumer foods',
#        'Farm-level cattle', 'Wholesale beef', 'Wholesale pork',
#        'Wholesale poultry', 'Farm-level eggs', 'Farm-level milk',
#        'Wholesale dairy', 'Farm-level soybeans',
#        'Wholesale fats and oils', 'Farm-level fruit',
#        'Farm-level vegetables', 'Farm-level wheat',
#        'Wholesale wheat flour'], dtype=object)

# %%
forecast["Top-level"].unique()
# Out:
# array(['All food'], dtype=object)
